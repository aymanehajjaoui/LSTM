# %% [markdown]
# # Imports

# %%
# %matplotlib notebook
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from scipy.signal import savgol_filter, resample
from tensorflow.keras.layers import Input

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

from sklearn.preprocessing import MinMaxScaler,StandardScaler

from scipy.stats import pearsonr
import seaborn as sns

# %% [markdown]
# # Load Data

# %%
# Dataset ID
date_id = "20250319"
record_id = "200"
segment_length = 48

# Path to dataset folder
dataset_path = f"../../../datasets/xydataset/csv/s{date_id}/s{date_id}_{record_id}/{segment_length}"

# Load CSVs
X_train = pd.read_csv(f"{dataset_path}/x_train.csv").values
X_test = pd.read_csv(f"{dataset_path}/x_test.csv").values
y_train = pd.read_csv(f"{dataset_path}/y_train.csv").values
y_test = pd.read_csv(f"{dataset_path}/y_test.csv").values

# Reshape X to (samples, timesteps, features) for LSTM
X_train = X_train.reshape(-1, segment_length, 1)
X_test = X_test.reshape(-1, segment_length, 1)

print("Loaded shapes:")
print("X_train:", X_train.shape)
print("y_train:", y_train.shape)
print("X_test:", X_test.shape)
print("y_test:", y_test.shape)
# Out:
# Loaded shapes:
# X_train: (799, 48, 1)
# y_train: (799, 1)
# X_test: (199, 48, 1)
# y_test: (199, 1)

# %% [markdown]
# # Plot Loaded Data (4 Subplots)

# %%
# Flatten for continuous plotting
X_train_cont = X_train.squeeze().flatten()
X_test_cont = X_test.squeeze().flatten()
y_train_cont = y_train.flatten()
y_test_cont = y_test.flatten()

# Create time axes
t_X_train = np.arange(len(X_train_cont))
t_X_test = np.arange(len(X_test_cont))
t_y_train = np.arange(len(y_train_cont))
t_y_test = np.arange(len(y_test_cont))

# Plot the data
plt.figure(figsize=(14, 10))

plt.subplot(2, 2, 1)
plt.plot(t_X_train, X_train_cont, color='blue')
plt.title("X_train")
plt.ylabel("Amplitude")
plt.grid(True)

plt.subplot(2, 2, 2)
plt.plot(t_y_train, y_train_cont, color='red')
plt.title("y_train")
plt.ylabel("Velocity")
plt.grid(True)

plt.subplot(2, 2, 3)
plt.plot(t_X_test, X_test_cont, color='green')
plt.title("X_test")
plt.xlabel("Time step")
plt.ylabel("Amplitude")
plt.grid(True)

plt.subplot(2, 2, 4)
plt.plot(t_y_test, y_test_cont, color='orange')
plt.title("y_test")
plt.xlabel("Sample index")
plt.ylabel("Velocity")
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1400">

# %% [markdown]
# # Scale data

# %%
scaling_method = ""

# Choose scalers based on method
if scaling_method == "minmax_01":
    scaler_X = MinMaxScaler(feature_range=(0, 1))
    scaler_y = MinMaxScaler(feature_range=(0, 1))
elif scaling_method == "minmax_11":
    scaler_X = MinMaxScaler(feature_range=(-1, 1))
    scaler_y = MinMaxScaler(feature_range=(-1, 1))
else:  # Default to standard
    scaler_X = StandardScaler()
    scaler_y = StandardScaler()

# Apply scaling to X
X_train_scaled = scaler_X.fit_transform(X_train.reshape(-1, X_train.shape[1])).reshape(X_train.shape)
X_test_scaled = scaler_X.transform(X_test.reshape(-1, X_test.shape[1])).reshape(X_test.shape)

# Apply scaling to y
y_train_scaled = scaler_y.fit_transform(y_train)
y_test_scaled = scaler_y.transform(y_test)

# %% [markdown]
# # Plot scalled data

# %%
# Flatten the 3D inputs (X) for plotting
X_train_scaled_cont = X_train_scaled.reshape(-1)
X_test_scaled_cont = X_test_scaled.reshape(-1)
y_train_scaled_cont = y_train_scaled.flatten()
y_test_scaled_cont = y_test_scaled.flatten()

# Create time axes
t_X_train = np.linspace(0, len(X_train_scaled_cont), len(X_train_scaled_cont))
t_X_test = np.linspace(0, len(X_test_scaled_cont), len(X_test_scaled_cont))
t_y_train = np.linspace(0, len(y_train_scaled_cont), len(y_train_scaled_cont))
t_y_test = np.linspace(0, len(y_test_scaled_cont), len(y_test_scaled_cont))

# Plot
plt.figure(figsize=(14, 10))

plt.subplot(2, 2, 1)
plt.plot(t_X_train, X_train_scaled_cont, color='blue')
plt.title("X_train_scaled")
plt.ylabel("Amplitude (standardized)")
plt.grid(True)

plt.subplot(2, 2, 2)
plt.plot(t_y_train, y_train_scaled_cont, color='red')
plt.title("y_train_scaled")
plt.ylabel("Velocity (standardized)")
plt.grid(True)

plt.subplot(2, 2, 3)
plt.plot(t_X_test, X_test_scaled_cont, color='green')
plt.title("X_test_scaled")
plt.xlabel("Time step")
plt.ylabel("Amplitude (standardized)")
plt.grid(True)

plt.subplot(2, 2, 4)
plt.plot(t_y_test, y_test_scaled_cont, color='orange')
plt.title("y_test_scaled")
plt.xlabel("Sample index")
plt.ylabel("Velocity (standardized)")
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1400">

# %% [markdown]
# # LSTM model

# %%
# Shape
segment_length = X_train.shape[1]
num_features = X_train.shape[2]

# Model
model = Sequential()
model.add(Input(shape=(segment_length, num_features)))
model.add(LSTM(16))
model.add(Dense(8, activation='relu'))
model.add(Dense(1))

# Compile
model.compile(optimizer=Adam(learning_rate=0.001), loss='mse', metrics=['mae'])

# Summary
model.summary()

# Get the total number of parameters in the model
total_params = model.count_params()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_4 (LSTM)                   │ (None, 16)             │         1,152 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,297 (5.07 KB)
#  Trainable params: 1,297 (5.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Train Model

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
use_early_stop=True

if(use_early_stop):
    history = model.fit(
    X_train_scaled, y_train_scaled,
    epochs=100,
    validation_data=(X_test_scaled, y_test_scaled),
    batch_size=16,callbacks=[early_stop]
    )
else:
        history = model.fit(
    X_train_scaled, y_train_scaled,
    epochs=100,
    validation_data=(X_test_scaled, y_test_scaled),
    batch_size=16
    )
# Out:
# Epoch 1/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.0675 - mae: 0.9074 - val_loss: 0.8949 - val_mae: 0.8378
# Epoch 2/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9002 - mae: 0.8490 - val_loss: 0.7650 - val_mae: 0.7700
# Epoch 3/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7662 - mae: 0.7722 - val_loss: 0.5935 - val_mae: 0.6402
# Epoch 4/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5800 - mae: 0.6093 - val_loss: 0.4950 - val_mae: 0.5065
# Epoch 5/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5907 - mae: 0.5320 - val_loss: 0.4362 - val_mae: 0.4836
# Epoch 6/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4556 - mae: 0.4650 - val_loss: 0.4212 - val_mae: 0.4548
# Epoch 7/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4492 - mae: 0.4482 - val_loss: 0.4177 - val_mae: 0.4527
# Epoch 8/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4257 - mae: 0.4409 - val_loss: 0.4268 - val_mae: 0.4662
# Epoch 9/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4725 - mae: 0.4607 - val_loss: 0.4114 - val_mae: 0.4449
# Epoch 10/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4721 - mae: 0.4568 - val_loss: 0.4504 - val_mae: 0.4712
# Epoch 11/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4342 - mae: 0.4466 - val_loss: 0.4309 - val_mae: 0.4600
# Epoch 12/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4278 - mae: 0.4420 - val_loss: 0.4156 - val_mae: 0.4507
# Epoch 13/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5255 - mae: 0.4911 - val_loss: 0.4154 - val_mae: 0.4493
# Epoch 14/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4465 - mae: 0.4646 - val_loss: 0.4113 - val_mae: 0.4516
# Epoch 15/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4488 - mae: 0.4552 - val_loss: 0.4111 - val_mae: 0.4429
# Epoch 16/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4120 - mae: 0.4258 - val_loss: 0.4541 - val_mae: 0.4853
# Epoch 17/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4505 - mae: 0.4680 - val_loss: 0.4117 - val_mae: 0.4603
# Epoch 18/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4007 - mae: 0.4354 - val_loss: 0.4159 - val_mae: 0.4664
# Epoch 19/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4501 - mae: 0.4641 - val_loss: 0.4109 - val_mae: 0.4500
# Epoch 20/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4283 - mae: 0.4404 - val_loss: 0.4181 - val_mae: 0.4539
# Epoch 21/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3794 - mae: 0.4205 - val_loss: 0.4027 - val_mae: 0.4510
# Epoch 22/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4139 - mae: 0.4361 - val_loss: 0.4375 - val_mae: 0.4659
# Epoch 23/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5125 - mae: 0.4893 - val_loss: 0.4108 - val_mae: 0.4517
# Epoch 24/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4826 - mae: 0.4735 - val_loss: 0.4373 - val_mae: 0.4595
# Epoch 25/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4268 - mae: 0.4320 - val_loss: 0.4197 - val_mae: 0.4478
# Epoch 26/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4085 - mae: 0.4430 - val_loss: 0.4100 - val_mae: 0.4512
# Epoch 27/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4388 - mae: 0.4583 - val_loss: 0.4519 - val_mae: 0.4737
# Epoch 28/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4400 - mae: 0.4544 - val_loss: 0.4119 - val_mae: 0.4579
# Epoch 29/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3956 - mae: 0.4224 - val_loss: 0.4158 - val_mae: 0.4599
# Epoch 30/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4065 - mae: 0.4293 - val_loss: 0.4098 - val_mae: 0.4545
# Epoch 31/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4431 - mae: 0.4635 - val_loss: 0.4006 - val_mae: 0.4394
# Epoch 32/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3830 - mae: 0.4201 - val_loss: 0.4031 - val_mae: 0.4448
# Epoch 33/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4146 - mae: 0.4316 - val_loss: 0.3966 - val_mae: 0.4423
# Epoch 34/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3839 - mae: 0.4145 - val_loss: 0.4014 - val_mae: 0.4502
# Epoch 35/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3907 - mae: 0.4214 - val_loss: 0.4221 - val_mae: 0.4593
# Epoch 36/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4094 - mae: 0.4315 - val_loss: 0.4026 - val_mae: 0.4409
# Epoch 37/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4129 - mae: 0.4307 - val_loss: 0.4079 - val_mae: 0.4424
# Epoch 38/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4181 - mae: 0.4374 - val_loss: 0.4009 - val_mae: 0.4368
# Epoch 39/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4155 - mae: 0.4275 - val_loss: 0.3934 - val_mae: 0.4390
# Epoch 40/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4042 - mae: 0.4306 - val_loss: 0.4263 - val_mae: 0.4581
# Epoch 41/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4278 - mae: 0.4437 - val_loss: 0.4199 - val_mae: 0.4508
# Epoch 42/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4041 - mae: 0.4273 - val_loss: 0.4030 - val_mae: 0.4512
# Epoch 43/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3988 - mae: 0.4263 - val_loss: 0.4273 - val_mae: 0.4463
# Epoch 44/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3755 - mae: 0.4118 - val_loss: 0.4215 - val_mae: 0.4538
# Epoch 45/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3709 - mae: 0.4053 - val_loss: 0.4457 - val_mae: 0.4770
# Epoch 46/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4375 - mae: 0.4545 - val_loss: 0.3925 - val_mae: 0.4392
# Epoch 47/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4117 - mae: 0.4276 - val_loss: 0.4141 - val_mae: 0.4574
# Epoch 48/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4227 - mae: 0.4429 - val_loss: 0.4060 - val_mae: 0.4482
# Epoch 49/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4341 - mae: 0.4460 - val_loss: 0.4021 - val_mae: 0.4333
# Epoch 50/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3907 - mae: 0.4090 - val_loss: 0.3996 - val_mae: 0.4410
# Epoch 51/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3861 - mae: 0.4111 - val_loss: 0.3938 - val_mae: 0.4334
# Epoch 52/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4916 - mae: 0.4638 - val_loss: 0.3960 - val_mae: 0.4357
# Epoch 53/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4294 - mae: 0.4440 - val_loss: 0.3933 - val_mae: 0.4424
# Epoch 54/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3564 - mae: 0.3983 - val_loss: 0.3937 - val_mae: 0.4414
# Epoch 55/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3903 - mae: 0.4231 - val_loss: 0.3904 - val_mae: 0.4372
# Epoch 56/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4511 - mae: 0.4547 - val_loss: 0.3917 - val_mae: 0.4362
# Epoch 57/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3906 - mae: 0.4177 - val_loss: 0.4106 - val_mae: 0.4500
# Epoch 58/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4307 - mae: 0.4406 - val_loss: 0.4084 - val_mae: 0.4478
# Epoch 59/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4232 - mae: 0.4515 - val_loss: 0.3933 - val_mae: 0.4376
# Epoch 60/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3983 - mae: 0.4178 - val_loss: 0.4045 - val_mae: 0.4484
# Epoch 61/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3743 - mae: 0.4115 - val_loss: 0.3920 - val_mae: 0.4375
# Epoch 62/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4178 - mae: 0.4436 - val_loss: 0.4127 - val_mae: 0.4316
# Epoch 63/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4413 - mae: 0.4333 - val_loss: 0.4135 - val_mae: 0.4553
# Epoch 64/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3739 - mae: 0.4125 - val_loss: 0.4158 - val_mae: 0.4496
# Epoch 65/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3552 - mae: 0.3949 - val_loss: 0.4027 - val_mae: 0.4394

# %% [markdown]
# # Plotting Loss and MAE

# %%
# Plot Loss
plt.figure()
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.legend()
plt.grid(True)
plt.show()

# Plot MAE
plt.figure()
plt.plot(history.history['mae'], label='Training MAE')
plt.plot(history.history['val_mae'], label='Validation MAE')
plt.title('MAE over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Evaluate the model

# %%
# Evaluate on test set
test_loss, test_mae = model.evaluate(X_test_scaled, y_test_scaled, verbose=1)
print(f"\nTest Loss (MSE): {test_loss:.4f}")
print(f"Test MAE: {test_mae:.4f}")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3518 - mae: 0.4313
#
# Test Loss (MSE): 0.4013
# Test MAE: 0.4538

# %% [markdown]
# # Predict and Inverse-transform to original scale

# %%
# Predict on test data
y_pred_scaled = model.predict(X_test_scaled)

# Inverse transform to get back to original scale
y_pred = scaler_y.inverse_transform(y_pred_scaled)
y_true = scaler_y.inverse_transform(y_test_scaled)
# Out:
# WARNING:tensorflow:5 out of the last 12 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7fa4f0a50040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 12 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7fa4f0a50040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %%
# Pearson correlation coefficient
r_value, _ = pearsonr(y_true.flatten(), y_pred.flatten())
print(f"Pearson correlation coefficient (r): {r_value:.4f}")
# Out:
# Pearson correlation coefficient (r): 0.7586

# %% [markdown]
# # Plot prediction vs Ground Truth

# %%
plt.figure(figsize=(10, 5))
plt.plot(y_true[:100], label="True Velocity", color='blue')
plt.plot(y_pred[:100], label="Predicted Velocity", color='red', linestyle='--')
plt.xlabel("Sample Index")
plt.ylabel("Velocity")
plt.title("LSTM Prediction vs Ground Truth")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# # Regression Plot

# %%
plt.figure(figsize=(6, 6))
sns.regplot(x=y_true.flatten(), y=y_pred.flatten(), line_kws={"color": "red"})
plt.xlabel("True Velocity")
plt.ylabel("Predicted Velocity")
plt.title(f"Regression Plot\nPearson r = {r_value:.4f}")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# # Save Model

# %%
save_dir = f"saved_models/{segment_length}"
os.makedirs(save_dir, exist_ok=True)

# Save model with total parameters in the filename
model.save(os.path.join(save_dir, f"{r_value}pearson_{total_params}params.h5"), include_optimizer=False)
print(f"Model saved")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved
